# %% [markdown]
# <a href="https://colab.research.google.com/github/shmiiing/ml_groupwork/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Modules & Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
url_X_train = 'https://github.com/shmiiing/ml_groupwork/raw/refs/heads/main/X_train.parquet'
X_train = pd.read_parquet(url_X_train)
X_train.head()
# Out:
#    stock_id        date  piot_norm       dsi      dtcn     ddtcn  \
# 0         1  2014-02-25        NaN       NaN       NaN       NaN
# 1         1  2014-05-07      0.875       NaN       NaN       NaN
# 2         1  2014-07-30      0.875       NaN       NaN       NaN
# 3         1  2014-10-29      0.875       NaN       NaN       NaN
# 4         1  2015-02-13      0.875  0.004025  1.134529 -0.362399
#
#    short_interest  asset_turnover_ratio  current_liabilities  ev_to_ebit  ...  \
# 0       1406440.0                   NaN                  NaN         NaN  ...
# 1       2216110.0              0.236071         2.090000e+09     24.9368  ...
# 2       2183770.0              0.236071         2.090000e+09     24.9368  ...
# 3       4279720.0              0.236071         2.090000e+09     24.9368  ...
# 4       1931410.0              0.236071         2.090000e+09     24.9368  ...
#
#       deps  value_mean_eps  value_smart_eps  value_split_adj_mean_eps  \
# 0      NaN        0.240994              NaN                   0.49452
# 1 -0.00147        0.125585         0.124868                   0.25770
# 2  0.00150        0.277427         0.278158                   0.56928
# 3  0.00726        0.243772         0.247632                   0.50022
# 4  0.00741        0.261184         0.264795                   0.53595
#
#    value_split_adj_smart_eps  MASK_EARNINGS             gics_sector  \
# 0                        NaN              1  Consumer Discretionary
# 1                    0.25623              1  Consumer Discretionary
# 2                    0.57078              1  Consumer Discretionary
# 3                    0.50814              1  Consumer Discretionary
# 4                    0.54336              1  Consumer Discretionary
#
#           gics_group                  gics_industry  \
# 0  Consumer Services  Hotels, Restaurants & Leisure
# 1  Consumer Services  Hotels, Restaurants & Leisure
# 2  Consumer Services  Hotels, Restaurants & Leisure
# 3  Consumer Services  Hotels, Restaurants & Leisure
# 4  Consumer Services  Hotels, Restaurants & Leisure
#
#                  gics_subindustry
# 0  Hotels, Resorts & Cruise Lines
# 1  Hotels, Resorts & Cruise Lines
# 2  Hotels, Resorts & Cruise Lines
# 3  Hotels, Resorts & Cruise Lines
# 4  Hotels, Resorts & Cruise Lines
#
# [5 rows x 40 columns]

# %%
url_DummyX_test = 'https://github.com/shmiiing/ml_groupwork/raw/refs/heads/main/DummyX_test.parquet'
DummyX_test = pd.read_parquet(url_DummyX_test)
DummyX_test.head()
# Out:
#     stock_id        date  piot_norm       dsi       dtcn     ddtcn  \
# 33         1  2022-04-29   0.559694  0.029782   3.374708 -8.124451
# 34         1  2022-07-25   0.578449  0.010995  15.544933 -4.274415
# 35         1  2022-10-24   0.644343  0.161878  12.139300  3.901776
# 36         1  2023-02-07   0.585925  0.030798   1.942343  1.305056
# 37         1  2023-04-24   0.680869  0.016672   0.610124 -1.093660
#
#     short_interest  asset_turnover_ratio  current_liabilities  ev_to_ebit  \
# 33    1.495047e+07              1.895862         2.378440e+09  124.073778
# 34    1.850066e+07              1.337111         1.169435e+09  157.346782
# 35   -3.592270e+05              1.484437         9.942401e+10         NaN
# 36   -9.286998e+04              0.058715         4.632626e+09         NaN
# 37    5.246288e+06              0.407839         1.305684e+09   80.983611
#
#     ...      deps  value_mean_eps  value_smart_eps  value_split_adj_mean_eps  \
# 33  ... -0.119742        1.329654         0.880482                  0.961276
# 34  ... -0.020472        2.559878        10.052196                  0.254823
# 35  ... -0.007814        1.315210         0.076584                  2.063647
# 36  ...  0.055312       -0.050804         0.398179                  0.825654
# 37  ...  0.148465        0.229002         0.140618                  0.133723
#
#     value_split_adj_smart_eps  MASK_EARNINGS             gics_sector  \
# 33                   0.846399            1.0  Communication Services
# 34                  -0.064558            1.0        Consumer Staples
# 35                  -0.745158            1.0              Financials
# 36                   0.448080            1.0                  Energy
# 37                   0.538057            1.0        Consumer Staples
#
#                          gics_group  \
# 33      Consumer Durables & Apparel
# 34              Software & Services
# 35                        Utilities
# 36                Consumer Services
# 37  Technology Hardware & Equipment
#
#                                      gics_industry  \
# 33                                Consumer Finance
# 34                            Hotel & Resort REITs
# 35                          Containers & Packaging
# 36                                Broadline Retail
# 37  Mortgage Real Estate Investment Trusts (REITs)
#
#                         gics_subindustry
# 33                          Timber REITs
# 34  Fertilizers & Agricultural Chemicals
# 35    Electronic Equipment & Instruments
# 36    Electronic Equipment & Instruments
# 37                    Leisure Facilities
#
# [5 rows x 40 columns]

# %%
url_y_train = 'https://github.com/shmiiing/ml_groupwork/raw/refs/heads/main/y_train.parquet'
y_train = pd.read_parquet(url_y_train)
y_train.head()
# Out:
#    stock_id       date  adjusted_close  auxiliary_target_1  \
# 0         1 2014-02-25         43.4775            0.000000
# 1         1 2014-05-07         44.0411            0.402140
# 2         1 2014-07-30         47.9671            0.114653
# 3         1 2014-10-29         47.7339            0.033862
# 4         1 2015-02-13         55.5276           -0.062309
#
#    auxiliary_target_2  forward_return
# 0           -3.517415       -0.002219
# 1           -2.724038        0.018992
# 2           -3.088564        0.003305
# 3           -3.151757        0.009196
# 4           -3.400788       -0.003840

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Data Preperation

# %% [markdown]
# # Feature Engineering

# %%
# LASSO --- 思羽

# %%
# catboost --- 周一鸣

# %%
# random forest --- 邵梓铭
